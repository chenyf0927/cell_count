# %%
import os,shutil
ROOT_DIR = os.path.abspath("")

# %%
ROOT_DIR
# Out:
# '/root/users/chenyf1'

# %%
mSCdata_dir = os.path.join(ROOT_DIR,"resize_msc/mSC")

# mask_dir = os.path.join(ROOT_DIR,"mSCdata/mask")

# %%
mSCdata_dir
# Out:
# '/root/users/chenyf1/resize_msc/mSC'

# %%
all_set = os.listdir(mSCdata_dir)

# mask_set = os.listdir(mask_dir)

# %%
from PIL import Image

# %%
for i in all_set:
    imgpath = os.path.join(mSCdata_dir,i)
    print(imgpath)
    img = Image.open(imgpath)
    img2 = img.resize((1024,1022))
    img2.save(imgpath)
# Out:
# /root/users/chenyf1/resize_msc/mSC/Image_130323.tif
# /root/users/chenyf1/resize_msc/mSC/Image_100826.tif
# /root/users/chenyf1/resize_msc/mSC/IMG_20180415_034230.jpg
# /root/users/chenyf1/resize_msc/mSC/Image_102904.tif
# /root/users/chenyf1/resize_msc/mSC/Image_100771.tif
# /root/users/chenyf1/resize_msc/mSC/Image_110359.tif
# /root/users/chenyf1/resize_msc/mSC/Image_121896.tif
# /root/users/chenyf1/resize_msc/mSC/Image_130308.tif
# /root/users/chenyf1/resize_msc/mSC/Image_108837.tif
# /root/users/chenyf1/resize_msc/mSC/Image_105851.tif
# /root/users/chenyf1/resize_msc/mSC/Image_102847.tif
# /root/users/chenyf1/resize_msc/mSC/Image_122993.jpg
# /root/users/chenyf1/resize_msc/mSC/Image_127948.tif
# /root/users/chenyf1/resize_msc/mSC/Image_129812.tif
# /root/users/chenyf1/resize_msc/mSC/Image_102943.tif
# /root/users/chenyf1/resize_msc/mSC/Image_102616.tif
# /root/users/chenyf1/resize_msc/mSC/001.tif
# /root/users/chenyf1/resize_msc/mSC/Image_106491.tif
# ...

# %%
for i in all_set:
    imgpath = os.path.join(mSCdata_dir,i)
    img = Image.open(imgpath)
    print((img.size))
# Out:
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# (1024, 1022)
# ...
